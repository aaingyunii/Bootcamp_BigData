# %%
import pandas as pd

# %%
df = pd.read_csv("https://drive.google.com/uc?id=1E8HUy1deJAVtrPbZ6quuJ39ujyMMQ_xq",header=None)

# %%
df_col=["id",
        "date",
        "route_id",
        "vh_id",
        "route_nm",       
        "now_arrive_time",   
        "now_latitude",            
        "now_longitude",
        "now_station",
        "distance",  
        "next_station",     
        "next_latitude",                   
        "next_longitude",
        "next_arrive_time"
]

# %%
df.columns=df_col

# %%
df
# Out:
#             id        date   route_id    vh_id route_nm  now_arrive_time  \
# 0            0  2019-10-15  405136001  7997025    360-1                6
# 1            1  2019-10-15  405136001  7997025    360-1                6
# 2            2  2019-10-15  405136001  7997025    360-1                6
# 3            3  2019-10-15  405136001  7997025    360-1                6
# 4            4  2019-10-15  405136001  7997025    360-1                7
# ...        ...         ...        ...      ...      ...              ...
# 210452  210452  2019-10-28  405328102  7983486    281-2               21
# 210453  210453  2019-10-28  405328102  7983486    281-2               21
# 210454  210454  2019-10-28  405328102  7983486    281-2               21
# 210455  210455  2019-10-28  405328102  7983486    281-2               21
# 210456  210456  2019-10-28  405328102  7983486    281-2               21
#
#         now_latitude  now_longitude   now_station  distance     next_station  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210457 entries, 0 to 210456
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                210457 non-null  int64
#  1   date              210457 non-null  object
#  2   route_id          210457 non-null  int64
#  3   vh_id             210457 non-null  int64
#  4   route_nm          210457 non-null  object
#  5   now_arrive_time   210457 non-null  int64
#  6   now_latitude      210457 non-null  float64
#  7   now_longitude     210457 non-null  float64
#  8   now_station       210457 non-null  object
#  9   distance          210457 non-null  int64
#  10  next_station      210457 non-null  object
#  11  next_latitude     210457 non-null  float64
#  12  next_longitude    210457 non-null  float64
#  13  next_arrive_time  210457 non-null  int64
# dtypes: float64(4), int64(6), object(4)
# memory usage: 22.5+ MB

# %%
df['now_station'].nunique()
# Out:
# 348

# %%
df['now_station'].value_counts()
# Out:
# now_station
# 남국원(아라방면)     3361
# 아라주공아파트       3098
# 도호동           3093
# 인다마을          3056
# 은남동           2789
#               ...
# 상도리 세화고등학교      25
# 오조리상동입구         21
# 세화고등학교          18
# 하도리 개긋물         11
# 전경대 입구           7
# Name: count, Length: 348, dtype: int64

# %%
stations = df['now_station'].value_counts()
filtered_stations = stations[stations >= 1000]
filtered_stations
# Out:
# now_station
# 남국원(아라방면)          3361
# 아라주공아파트            3098
# 도호동                3093
# 인다마을               3056
# 은남동                2789
#                    ...
# 광양                 1034
# 관덕정                1022
# 월성 마을              1020
# 김녕환승정류장(김녕초등학교)    1020
# 영천동주민센터            1009
# Name: count, Length: 65, dtype: int64

# %%
route_405136522 = df[df['route_id'] == 405136522]
route_405136522_20191015 = route_405136522[route_405136522['date']=='2019-10-15']
route_405136522_20191015[route_405136522_20191015['vh_id'] == 7997002].head(45)
# Out:
#         id        date   route_id    vh_id route_nm  now_arrive_time  \
# 3978  3978  2019-10-15  405136522  7997002   365-22                6
# 3979  3979  2019-10-15  405136522  7997002   365-22                6
# 3980  3980  2019-10-15  405136522  7997002   365-22                6
# 3981  3981  2019-10-15  405136522  7997002   365-22                6
# 3982  3982  2019-10-15  405136522  7997002   365-22                6
# 3983  3983  2019-10-15  405136522  7997002   365-22                6
# 3984  3984  2019-10-15  405136522  7997002   365-22                6
# 3985  3985  2019-10-15  405136522  7997002   365-22                6
# 3986  3986  2019-10-15  405136522  7997002   365-22                6
# 3987  3987  2019-10-15  405136522  7997002   365-22                6
# 3988  3988  2019-10-15  405136522  7997002   365-22                6
# 3989  3989  2019-10-15  405136522  7997002   365-22                6
# 3990  3990  2019-10-15  405136522  7997002   365-22                6
# ...

# %%
route_405136522_20191015[route_405136522_20191015['now_station'] == '도호동'].head(45)
# Out:
#         id        date   route_id    vh_id route_nm  now_arrive_time  \
# 3985  3985  2019-10-15  405136522  7997002   365-22                6
# 4019  4019  2019-10-15  405136522  7997002   365-22                8
# 4027  4027  2019-10-15  405136522  7997002   365-22                9
# 4065  4065  2019-10-15  405136522  7997002   365-22               12
# 4100  4100  2019-10-15  405136522  7997002   365-22               16
# 4128  4128  2019-10-15  405136522  7997002   365-22               19
# 4169  4169  2019-10-15  405136522  7997022   365-22                7
# 4197  4197  2019-10-15  405136522  7997022   365-22               10
# 4205  4205  2019-10-15  405136522  7997022   365-22               11
# 4238  4238  2019-10-15  405136522  7997022   365-22               13
# 4246  4246  2019-10-15  405136522  7997022   365-22               14
# 4278  4278  2019-10-15  405136522  7997022   365-22               17
# 4286  4286  2019-10-15  405136522  7997022   365-22               18
# ...

# %%
tmp_df = df[df['date'] == '2019-10-15']

# %%
tmp_df[tmp_df['now_station'] == "도호동"]
# Out:
#         id        date   route_id    vh_id route_nm  now_arrive_time  \
# 4        4  2019-10-15  405136001  7997025    360-1                7
# 15      15  2019-10-15  405136001  7997025    360-1                8
# 47      47  2019-10-15  405136001  7997025    360-1               11
# 66      66  2019-10-15  405136001  7997025    360-1               13
# 79      79  2019-10-15  405136001  7997025    360-1               14
# ...    ...         ...        ...      ...      ...              ...
# 6347  6347  2019-10-15  405136522  7997120   365-22               14
# 6371  6371  2019-10-15  405136522  7997120   365-22               17
# 6379  6379  2019-10-15  405136522  7997120   365-22               18
# 6413  6413  2019-10-15  405136522  7997120   365-22               20
# 6421  6421  2019-10-15  405136522  7997120   365-22               21
#
#       now_latitude  now_longitude now_station  distance next_station  \
# ...

# %%
tmp_df2 = tmp_df[tmp_df['now_station'] == "제대아파트"]
tmp_df2
# Out:
#         id        date   route_id    vh_id route_nm  now_arrive_time  \
# 2        2  2019-10-15  405136001  7997025    360-1                6
# 35      35  2019-10-15  405136001  7997025    360-1                8
# 103    103  2019-10-15  405136001  7997025    360-1               14
# 141    141  2019-10-15  405136001  7997025    360-1               18
# 180    180  2019-10-15  405136001  7997025    360-1               21
# ...    ...         ...        ...      ...      ...              ...
# 6261  6261  2019-10-15  405136522  7997119   365-22               18
# 6298  6298  2019-10-15  405136522  7997119   365-22               22
# 6335  6335  2019-10-15  405136522  7997120   365-22               11
# 6369  6369  2019-10-15  405136522  7997120   365-22               15
# 6407  6407  2019-10-15  405136522  7997120   365-22               19
#
#       now_latitude  now_longitude now_station  distance next_station  \
# ...

# %% [markdown]
# ### 버스를 구분하는 것은 `vh_id` 컬럼
# ### `route_id`, 즉 같은 노선이면 `vh_id` 가 달라도 같은 `route_nm` 을 부여한다.
# ### `route_id` ==== `route_nm` : 동일 취급
